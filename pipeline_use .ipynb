# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv(r'C:\Users\SDS\Downloads\train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# remove unusal clumn from data set 

df.drop(columns=['PassengerId','Cabin','Fare','Ticket','Name'],inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0           0       3    male  22.0      1      0        S
# 1           1       1  female  38.0      1      0        C
# 2           1       3  female  26.0      0      0        S
# 3           1       1  female  35.0      1      0        S
# 4           0       3    male  35.0      0      0        S
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0        S
# 887         1       1  female  19.0      0      0        S
# 888         0       3  female   NaN      1      2        S
# 889         1       1    male  26.0      0      0        C
# 890         0       3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
#target column
x=df.drop(columns=['Survived'])
y=df['Survived']

# %%
# train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
y_train.shape
# Out:
# (712,)

# %%
#fill the null value 
tf1=ColumnTransformer([('age_imputer ',SimpleImputer(),[2]),
                    ('emabrked_imputer ',SimpleImputer(strategy='most_frequent'),[5])],remainder='passthrough')

# %%
tf1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('age_imputer ', SimpleImputer(), [2]),
#                                 ('emabrked_imputer ',
#                                  SimpleImputer(strategy='most_frequent'),
#                                  [5])])

# %%
# one hot encoding
tf2=ColumnTransformer([('sex',OneHotEncoder(sparse=False,handle_unknown='ignore'),[1,5])],remainder='passthrough')

# %%
tf2
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('sex',
#                                  OneHotEncoder(handle_unknown='ignore',
#                                                sparse=False),
#                                  [1, 5])])

# %%
#scaling
tf3=ColumnTransformer([('scaling',MinMaxScaler(),slice(0,10))])

# %%
tf3
# Out:
# ColumnTransformer(transformers=[('scaling', MinMaxScaler(),
#                                  slice(0, 10, None))])

# %%
# algoritham
tf4=DecisionTreeClassifier()

# %%
tf4
# Out:
# DecisionTreeClassifier()

# %%
pipe=Pipeline([('tf1',tf1),
             ('tf2',tf2),
               ('tf3',tf3),
               ('tf4',tf4)
               
             
              ])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('age_imputer ',
#                                                   SimpleImputer(), [2]),
#                                                  ('emabrked_imputer ',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [5])])),
#                 ('tf2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('sex',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   [1, 5])])),
#                 ('tf3',
#                  ColumnTransformer(transformers=[('scaling', MinMaxScaler(),
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred=pipe.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9106145251396648
